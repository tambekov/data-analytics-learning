# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://stepik.org/media/attachments/course/72204/gff.tsv", sep="\t")

# %%
df.head()
# Out:
#   seq_id  source            type    start      end score strand phase  \
# 0  chr17  RefSeq            exon  6811330  6811453     .      +     .
# 1  chr17  RefSeq             CDS  6808204  6808245     .      +     0
# 2  chr17  RefSeq             CDS  6811792  6811869     .      +     2
# 3  chr17  RefSeq            exon  6806513  6806553     .      +     .
# 4  chr17  RefSeq  five_prime_UTR  6806513  6806526     .      +     .
#
#                                           attributes
# 0                              Parent=XM_001475631.1
# 1  Name=CDS:NC_000083.5:LOC100040603;Parent=XM_00...
# 2  Name=CDS:NC_000083.5:LOC100040603;Parent=XM_00...
# 3                              Parent=XM_001475631.1
# 4                              Parent=XM_001475631.1

# %%
df.attributes.str.split('=')[1]
# Out:
# ['Name', 'CDS:NC_000083.5:LOC100040603;Parent', 'XM_001475631.1,']

# %%
only_parent_atr = df[df.attributes.str.startswith('Parent')]

# %%
only_parent_atr['value_of_attr'] = only_parent_atr.attributes.apply(lambda x :x.split('=')[-1])

# %%
only_parent_atr.value_of_attr.value_counts()
# Out:
# value_of_attr
# XM_001475631.1    280
# Name: count, dtype: int64

# %%
temp = df.type.value_counts().sort_values(ascending=False)
temp
# Out:
# type
# exon               201
# CDS                170
# five_prime_UTR      47
# mRNA                33
# three_prime_UTR     32
# protein             29
# Name: count, dtype: int64

# %%
sns.barplot(temp)
# Out:
# <Axes: xlabel='type', ylabel='count'>
